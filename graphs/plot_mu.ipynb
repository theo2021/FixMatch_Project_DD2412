# %%
from matplotlib import pyplot as plt
from ploting import *

# %%
directory = 'mu_1/'
mu_1 = get_data(directory + 'events.out.tfevents.1605122397.deeplearningadvanced-vm.4475.0')
directory = 'mu_3/'
mu_3 = get_data(directory + 'events.out.tfevents.1605168784.deeplearningadvanced-vm.2252.0')
directory = 'mu_7/'
mu_7 = get_data(directory + 'events.out.tfevents.1605184028.deeplearningadvanced-vm.20021.0')

# %%
plt.figure(figsize=(8,5))
col = 'Accuracy/validation'
plot_val(mu_7[col], label='7', color='red')
plot_val(mu_3[col], label='3', color='green')
plot_val(mu_1[col], label='1')
plt.legend(loc="upper left")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
mu_1.keys()
# Out:
# dict_keys(['Loss/train', 'SupervisedLoss/train', 'UnsupervisedLoss/train', 'Psudolabel_num/train', 'Learning_Rate/train', 'Accuracy/validation'])
